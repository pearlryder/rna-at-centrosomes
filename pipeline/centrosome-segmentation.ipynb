# %%
# IO packages
from aicsimageio import AICSImage
import os
import imageio

# calculation packages
import numpy as np

# segmentation packages
from aicssegmentation.core.pre_processing_utils import intensity_normalization, image_smoothing_gaussian_slice_by_slice
from aicssegmentation.core.seg_dot import dot_3d_wrapper
from skimage.morphology import dilation, ball, remove_small_objects

# watershed packages
from skimage.segmentation import watershed
from skimage.feature import peak_local_max
from scipy.ndimage import distance_transform_edt
from skimage.measure import label

# %%
def segment_centrosomes(image_name, filepath, s3_param, output_path):
    """ Takes a filepath that is a single channel tif as an input
    Segments the image - optimized for centrosomes
    Returns a segmented image
    """
        
    print('Segmenting centrosomes for ' + filepath)

    
    reader = AICSImage(filepath) 
    IMG = reader.data

    #####################
    structure_channel = 0
    #####################

    structure_img0 = IMG[0,structure_channel,:,:,:]
        
    ################################
    ## PARAMETER ##
    intensity_scaling_param = [0]
    gaussian_smoothing_sigma = 1
    ################################

    # intensity normalization
    structure_img = intensity_normalization(structure_img0, scaling_param=intensity_scaling_param)

    # smoothing with gaussian filter
    structure_img_smooth = image_smoothing_gaussian_slice_by_slice(structure_img, sigma=gaussian_smoothing_sigma)
    
    ################################
    ## Detect spots w/ 3D dot wrapper ##
    ## Parameters are optimized to stage and RNA type ##
    bw = dot_3d_wrapper(structure_img_smooth, s3_param)

    ################################
    ## PARAMETERS for removing small objects ##
    minArea = 200
    ################################

    final_seg = remove_small_objects(bw>0, min_size=minArea, connectivity=1, in_place=False)
    
    ################################
    ## SAVE TO DISK
    ################################
    
    output_seg = final_seg>0
    out=output_seg.astype(np.uint8)
    out[out>0]=255
    imageio.volwrite(output_path + image_name, out)

        
    return None

# %%
centrosome_raw_data_dir = '/Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/'

output_path = '/Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/segmentations/'

s3_param = [[1, 0.02]]


image_ls = os.listdir(centrosome_raw_data_dir)

for image_name in image_ls:
    if not image_name[0] == '.':
        image_path = os.path.join(centrosome_raw_data_dir, image_name)

        segment_centrosomes(image_name, image_path, s3_param, output_path)
# Out:
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide254_img_007.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide254_img_013.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_Slide_261_Img_015.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide121_009.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide256_img_001.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide253_img_010.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC14_interphase_Emb3_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide253_img_004.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide045_Emb32.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_metaphase_slide265_img001.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC12_interphase_Slide065_Emb009.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide259_img013.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC12_interphase_Slide065_Emb008.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_Slide045_Emb7.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_metaphase_slide251_img_008.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_slide265_img004.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide253_img_005.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_Slide22_CnnGFP_cenmRNA_Emb10_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide260_img008.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide256_img_002.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_Slide_261_Img_002.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_slide265_img006.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_slide266_img008.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_Slide045_Emb5.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide259_img011.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide259_img010.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide260_img009.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_slide266_img009.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_metaphase_slide265_img003.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide253_img_006.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_Slide038_Emb29_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide259_img004.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_Slide038_Emb27_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide254_img_005.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide254_img_011.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide040_Emb57_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide263_img017.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_Slide039_Emb61_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide045_Emb19_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide256_img_007.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide253_img_002.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide059_Emb10.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide256_img_008.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_metaphase_slide265_img007.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide251_img_010.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide_238_Img_001.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_Slide040_Emb18_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide256_img_009.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_slide265_img002.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_Slide037_Emb49_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide045_Emb35.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_interphase_Slide037_Emb48_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide059_Emb11.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide253_img_003.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide256_img_006.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide259_img015.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide263_img016.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide_261_Img_024.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide254_img_014.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide254_img_016.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide_261_Img_026.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide263_img014.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_metaphase_Slide037_Emb47_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_metaphase_slide254_img_009.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide256_img_004.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_metaphase_Slide039_Emb50_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_slide251_img_007.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_metaphase_Slide059_Emb7.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_slide259_img002.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_Slide038_Emb30_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC10_metaphase_slide265_img005.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_Slide22_CnnGFP_cenmRNA_Emb1_Img1.tif
# intensity normalization: using min-max normalization with NO absolute intensity upper bound
# intensity normalization completes
# Segmenting centrosomes for /Users/pearlryder/data/resubmission-analysis-2/data/centrosomes/raw-data/NC13_interphase_sl